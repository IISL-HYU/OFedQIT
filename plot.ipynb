# %% [markdown]
# #### dohyeok

# %%
import pickle
import matplotlib.pyplot as plt

with open("./Classification_Acc_dohyeok/OFedAvg_Occp_p0.1.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open("./Classification_Acc_dohyeok/OFedQIT_Occp_L1_s1_p0.1.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

with open("./Classification_Acc_dohyeok/OFedQIT_Occp_L10_s1_p0.1.pkl","rb") as f:
    ofl_sel_mse3 = pickle.load(f)

    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
t3 = list(range(len(ofl_sel_mse3)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
y3 = ofl_sel_mse3
# y1.insert(0, 0)
# y2.insert(0, 0)
# y3.insert(0, 0)
# plotting the points
plt.plot(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)')
plt.plot(t2, y2, 'red', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{L=1}$, $\mathdefault{p=0.1}$)')
plt.plot(t3, y3, 'blue', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{L=10}$, $\mathdefault{p=0.1}$)')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('t')
# naming the y axis
plt.ylabel('Accuracy')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig('./Figures/Classification_Occupancy_OFedQIT_p=0.1.png', dpi=200, facecolor="white")
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

with open("./Regression_mse/OFedAvg_Air_p0.1.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open("./Regression_mse/OFedQIT_Air_L1_s1_p0.1.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

with open("./Regression_mse/OFedQIT_Air_L10_s1_p0.1.pkl","rb") as f:
    ofl_sel_mse3 = pickle.load(f)

    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
t3 = list(range(len(ofl_sel_mse3)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
y3 = ofl_sel_mse3
plt.plot(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)')
plt.plot(t2, y2, 'red', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{L=1}$, $\mathdefault{p=0.1}$)')
plt.plot(t3, y3, 'blue', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{L=10}$, $\mathdefault{p=0.1}$)')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('t')
# naming the y axis
plt.ylabel('MSE')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig('./Figures/Regression_Air_OFedQIT_p=0.1.png', dpi=200, facecolor="white")
plt.show()
