# %%
import pickle
import matplotlib.pyplot as plt

with open("./Regression_mse/OFedAvg_Conductivity.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open("./Regression_mse/OFedIT_Q_Conductivity.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
# plotting the points
plt.plot(t1, y1, 'black', label=r'OFedQIT ($\mathdefault{s=\infty}$, $\mathdefault{p=1}$)')
plt.plot(t2, y2, 'red', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{p=1}$)')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('t')
# naming the y axis
plt.ylabel('MSE')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig('./Figures/Regression_Conductivity_OFedQIT.png', dpi=200, facecolor="white")
plt.show()
# Out:
# /var/folders/x0/fxq35pnx7w97ps9113cz6mxc0000gn/T/ipykernel_31227/2794126138.py:19: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim([0, 1])

# %%
import pickle
import matplotlib.pyplot as plt

with open("./Regression_mse_dohyeok/OFedAvg_Cdt_p0.1.pkl","rb") as f:
    loss_list1 = pickle.load(f)

with open("./Regression_mse_dohyeok/OFedQIT_Wav_L10_s1_p0.1.pkl","rb") as f:
    loss_list2 = pickle.load(f)

with open("./Regression_mse_dohyeok/OFedAvg_Cdt_p0.5.pkl","rb") as f:
    loss_list3 = pickle.load(f)

with open("./Regression_mse_dohyeok/OFedAvg_Cdt_p1.0.pkl","rb") as f:
    loss_list4 = pickle.load(f)

    
t1 = list(range(len(loss_list1)))
t2 = list(range(len(loss_list2)))
t3 = list(range(len(loss_list3)))
t4 = list(range(len(loss_list4)))
y1 = loss_list1
y2 = loss_list2
y3 = loss_list3
y4 = loss_list4
# plotting the points
plt.semilogy(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{s=\infty}$, $\mathdefault{p=0.1}$)')
# plt.semilogy(t2, y2, 'red', label=r'OFedQIT ($\mathdefault{L=10}$, $\mathdefault{s=1}$, $\mathdefault{p=0.1}$)')
plt.semilogy(t3, y3, 'red', label=r'OFedAvg ($\mathdefault{s=\infty}$, $\mathdefault{p=0.5}$)')
plt.semilogy(t4, y4, 'blue', label=r'OFedAvg ($\mathdefault{s=\infty}$, $\mathdefault{p=1.0}$)')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('t')
# naming the y axis
plt.ylabel('MSE')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig('./Figures/Regression_Wav_p0.1.png', dpi=200, facecolor="white")
plt.show()
# Out:
# /var/folders/x0/fxq35pnx7w97ps9113cz6mxc0000gn/T/ipykernel_6508/2171285669.py:31: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim([0, 1])

# %%
import pickle
import matplotlib.pyplot as plt

with open("./Regression_mse/OFedAvg_Wav_p0.1_before.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open("./Regression_mse/OFedQIT_Wav_L10_s1_p0.1_before.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
# plotting the points
plt.semilogy(t1, y1, 'black', label=r'OFedQIT ($\mathdefault{s=\infty}$, $\mathdefault{p=1}$)')
plt.semilogy(t2, y2, 'red', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{p=1}$)')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('t')
# naming the y axis
plt.ylabel('MSE')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig('./Figures/Regression_Conductivity_OFedQIT.png', dpi=200, facecolor="white")
plt.show()
# Out:
# /var/folders/x0/fxq35pnx7w97ps9113cz6mxc0000gn/T/ipykernel_6508/3319327210.py:19: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim([0, 1])

# %%
import pickle
import matplotlib.pyplot as plt

with open("./Regression_mse/OFedAvg_Cdt_p0.1_after.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open("./Regression_mse/OFedQIT_Cdt_L10_s1_p0.1_after.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
# plotting the points
plt.plot(t1, y1, 'black', label=r'OFedQIT ($\mathdefault{s=\infty}$, $\mathdefault{p=1}$)')
plt.plot(t2, y2, 'red', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{p=1}$)')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('t')
# naming the y axis
plt.ylabel('MSE')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig('./Figures/Regression_Conductivity_OFedQIT.png', dpi=200, facecolor="white")
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

with open("./Regression_mse/OFedQIT_Cdt_L10_s1_p0.1_after.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open("./Regression_mse_dohyeok/OFedQIT_Cdt_L10_s1_p0.1.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
# plotting the points
plt.semilogy(t1, y1, 'black', label=r'OFedQIT ($\mathdefault{s=\infty}$, $\mathdefault{p=1}$)')
plt.semilogy(t2, y2, 'red', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{p=1}$)')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('t')
# naming the y axis
plt.ylabel('MSE')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig('./Figures/Regression_Conductivity_OFedQIT.png', dpi=200, facecolor="white")
plt.show()
# Out:
# <ipython-input-4-7215eab78cc9>:19: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim([0, 1])

# %% [markdown]
# #### dohyeok

# %%
import pickle
import matplotlib.pyplot as plt

with open("./Classification_Acc_dohyeok/OFedAvg_Occp_p1.0.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open("./Classification_Acc_dohyeok/OFedQIT_Occp_L10_s1_p1.0.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
# plotting the points
plt.plot(t1, y1, 'black', label=r'OFedQIT ($\mathdefault{s=\infty}$, $\mathdefault{p=1}$)')
plt.plot(t2, y2, 'red', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{p=1}$)')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('t')
# naming the y axis
plt.ylabel('MSE')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig('./Figures/Regression_Conductivity_OFedQIT.png', dpi=200, facecolor="white")
plt.show()
