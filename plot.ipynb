# %% [markdown]
# #### dohyeok

# %%
import pickle
import matplotlib.pyplot as plt

L = 1
L1 = 1
L2 = 3

prob = 0.1
data = "Occp"
b = 30

with open(f"./Classification_Acc/OFedAvg_{data}_L{L}_p{prob}.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open(f"./Classification_Acc/OFedQIT_{data}_L{L1}_s1_b{b}_p{prob}.pkl","rb") as f:
    ofl_sel_mse3 = pickle.load(f)

with open(f"./Classification_Acc/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob}.pkl","rb") as f:
    ofl_sel_mse4 = pickle.load(f)

    
t1 = list(range(len(ofl_sel_mse)))
t3 = list(range(len(ofl_sel_mse3)))
t4 = list(range(len(ofl_sel_mse4)))
y1 = ofl_sel_mse
y3 = ofl_sel_mse3
y4 = ofl_sel_mse4
# plotting the points
plt.plot(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)')
plt.plot(t3, y3, 'red', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{b=30}$, $\mathdefault{L=1}$, $\mathdefault{p=0.1}$)')
plt.plot(t4, y4, 'blue', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{b=30}$, $\mathdefault{L=3}$, $\mathdefault{p=0.1}$)')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('t')
# naming the y axis
plt.ylabel('Accuracy')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig(f'./Figures/Classification_Occupancy_OFedQIT_p={prob}_b={b}_combinations.png', dpi=200, facecolor="white")
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

with open("./Regression_mse/OFedAvg_Air_p0.1.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open("./Regression_mse/OFedQIT_Air_L1_s1_p0.1.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

with open("./Regression_mse/OFedQIT_Air_L10_s1_p0.1.pkl","rb") as f:
    ofl_sel_mse3 = pickle.load(f)

    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
t3 = list(range(len(ofl_sel_mse3)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
y3 = ofl_sel_mse3
plt.plot(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)')
plt.plot(t2, y2, 'red', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{L=1}$, $\mathdefault{p=0.1}$)')
plt.plot(t3, y3, 'blue', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{L=10}$, $\mathdefault{p=0.1}$)')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('t')
# naming the y axis
plt.ylabel('MSE')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig('./Figures/Regression_Air_OFedQIT_p=0.1.png', dpi=200, facecolor="white")
plt.show()

# %%
str = "scv%s%s" %"321" %"1"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-713f9b9cbaf2> in <module>
# ----> 1 str = "scv%s%s" %"321" %"1"
#
# TypeError: not enough arguments for format string

# %%
import pickle
import matplotlib.pyplot as plt

L = 1
L1 = 1
L2 = 2

prob = 1.0
prob2 = 0.1
data = "Occp"
b = 100

with open(f"./Classification_Acc/OFedAvg_{data}_L{L}_p{prob}.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open(f"./Classification_Acc/OFedAvg_{data}_L{L}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

with open(f"./Classification_Acc/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob}.pkl","rb") as f:
    ofl_sel_mse3 = pickle.load(f)

with open(f"./Classification_Acc/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse4 = pickle.load(f)
    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
t3 = list(range(len(ofl_sel_mse3)))
t4 = list(range(len(ofl_sel_mse4)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
y3 = ofl_sel_mse3
y4 = ofl_sel_mse4
# plotting the points
plt.plot(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=1.0}$)')
plt.plot(t2, y2, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)', linestyle='dashed')
plt.plot(t3, y3, 'red', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{b=100}$, $\mathdefault{L=2}$, $\mathdefault{p=1.0}$)')
plt.plot(t4, y4, 'red', label=r'OFedQIT ($\mathdefault{s=1}$, $\mathdefault{b=100}$, $\mathdefault{L=2}$, $\mathdefault{p=0.1}$)', linestyle='dashed')

plt.ylim([0.6, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('time index (t)')
# naming the y axis
plt.ylabel('Accuracy(t)')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig(f'./Figures/Classification_Occupancy_OFedQIT_p={prob}_b={b}_combinations_ver2.0.png', dpi=200, facecolor="white")
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

L = 1
L1 = 1
L2 = 2

prob = 1.0
prob2 = 0.1
data = "MNIST"
b = 1000

with open(f"./Classification_Acc/OFedAvg_{data}_L{L}_p{prob}.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open(f"./Classification_Acc/OFedAvg_{data}_L{L}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

with open(f"./Classification_Acc/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob}.pkl","rb") as f:
    ofl_sel_mse3 = pickle.load(f)

with open(f"./Classification_Acc/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse4 = pickle.load(f)
    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
t3 = list(range(len(ofl_sel_mse3)))
t4 = list(range(len(ofl_sel_mse4)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
y3 = ofl_sel_mse3
y4 = ofl_sel_mse4
# plotting the points
plt.plot(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=1.0}$)')
plt.plot(t3, y3, 'red', label=r'OFedQIT ($\mathdefault{p=1.0}$), 95.4% reduce')
plt.plot(t2, y2, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)', linestyle='dashed')
plt.plot(t4, y4, 'red', label=r'OFedQIT ($\mathdefault{p=0.1}$), 95.4% reduce', linestyle='dashed')

plt.ylim([0.5, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('time index (t)')
# naming the y axis
plt.ylabel('Accuracy (t)')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig(f'./Figures/Classification_{data}_OFedQIT_p={prob}_b={b}_combinations_ver2.0.png', dpi=200, facecolor="white")
plt.show()

# %%
diff1 = ofl_sel_mse[len(ofl_sel_mse)-1] - ofl_sel_mse3[len(ofl_sel_mse3)-1]
print(diff1)
diff2 = ofl_sel_mse2[len(ofl_sel_mse2)-1] - ofl_sel_mse4[len(ofl_sel_mse4)-1]
print(diff2)
# Out:
# 0.009735052585601811
# 0.0065026515722275136

# %%
import pickle
import matplotlib.pyplot as plt

L = 1
L1 = 1
L2 = 2

prob = 1.0
prob2 = 0.1
data = "Occp_v2"
b = 100

with open(f"./Classification_Acc/OFedAvg_{data}_L{L}_p{prob}.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open(f"./Classification_Acc/OFedAvg_{data}_L{L}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

with open(f"./Classification_Acc/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob}.pkl","rb") as f:
    ofl_sel_mse3 = pickle.load(f)

with open(f"./Classification_Acc/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse4 = pickle.load(f)
    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
t3 = list(range(len(ofl_sel_mse3)))
t4 = list(range(len(ofl_sel_mse4)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
y3 = ofl_sel_mse3
y4 = ofl_sel_mse4
# plotting the points
plt.plot(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=1.0}$)')
plt.plot(t3, y3, 'red', label=r'OFedQIT ($\mathdefault{p=1.0}$), 92.8% reduce')
plt.plot(t2, y2, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)', linestyle='dashed')
plt.plot(t4, y4, 'red', label=r'OFedQIT ($\mathdefault{p=0.1}$), 92.8% reduce', linestyle='dashed')

plt.ylim([0.5, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('time index (t)')
# naming the y axis
plt.ylabel('Accuracy (t)')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig(f'./Figures/Classification_{data}_OFedQIT_p={prob}_b={b}_combinations_ver2.0.png', dpi=200, facecolor="white")
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

L = 1
L3 = 3

prob = 1.0
prob3 = 0.1
data = "AirL"
b = 100

with open(f"./Regression_mse/OFedAvg_{data}_L{L}_p{prob}.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open(f"./Regression_mse/OFedAvg_{data}_L{L}_p{prob3}.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

with open(f"./Regression_mse/OFedQIT_{data}_L{L3}_s1_b{b}_p{prob}.pkl","rb") as f:
    ofl_sel_mse3 = pickle.load(f)

with open(f"./Regression_mse/OFedQIT_{data}_L{L3}_s1_b{b}_p{prob3}.pkl","rb") as f:
    ofl_sel_mse4 = pickle.load(f)
    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
t3 = list(range(len(ofl_sel_mse3)))
t4 = list(range(len(ofl_sel_mse4)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
y3 = ofl_sel_mse3
y4 = ofl_sel_mse4
# plotting the points
plt.semilogy(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=1.0}$)')
plt.semilogy(t3, y3, 'red', label=r'OFedQIT ($\mathdefault{p=1.0}$), 93.7% reduce')
plt.semilogy(t2, y2, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)', linestyle='dashed')
plt.semilogy(t4, y4, 'red', label=r'OFedQIT ($\mathdefault{p=0.1}$), 93.7% reduce', linestyle='dashed')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('time index ($t$)')
# naming the y axis
plt.ylabel('MSE ($t$)')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig(f'./Figures/Regression_{data}_OFedQIT_p={prob}_b={b}_combinations_ver2.0.png', dpi=200, facecolor="white")
plt.show()
# Out:
# /Users/parkjonghwan/opt/anaconda3/envs/learning/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.

# %%
len(ofl_sel_mse)
# Out:
# 988

# %%
import pickle
import matplotlib.pyplot as plt

L = 1
L1 = 1
L2 = 10

prob = 1.0
prob2 = 0.1
data = "Twit"
b = 1

with open(f"./Regression_mse/OFedAvg_{data}_L{L}_p{prob}.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open(f"./Regression_mse/OFedAvg_{data}_L{L}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

with open(f"./Regression_mse/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob}.pkl","rb") as f:
    ofl_sel_mse3 = pickle.load(f)

with open(f"./Regression_mse/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse4 = pickle.load(f)
    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
t3 = list(range(len(ofl_sel_mse3)))
t4 = list(range(len(ofl_sel_mse4)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
y3 = ofl_sel_mse3
y4 = ofl_sel_mse4
# plotting the points
plt.semilogy(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=1.0}$)')
plt.semilogy(t3, y3, 'red', label=r'OFedQIT ($\mathdefault{p=1.0}$), 99.3% reduce')
plt.semilogy(t2, y2, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)', linestyle='dashed')
plt.semilogy(t4, y4, 'red', label=r'OFedQIT ($\mathdefault{p=0.1}$), 99.3% reduce', linestyle='dashed')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('time index (t)')
# naming the y axis
plt.ylabel('MSE (t)')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig(f'./Figures/Regression_{data}_OFedQIT_p={prob}_b={b}_combinations_ver2.0.png', dpi=200, facecolor="white")
plt.show()
# Out:
# /Users/parkjonghwan/opt/anaconda3/envs/learning/lib/python3.7/site-packages/ipykernel_launcher.py:39: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.

# %%
import pickle
import matplotlib.pyplot as plt

L = 1
L1 = 1
L2 = 3

prob = 1.0
prob2 = 0.1
data = "CTG"
b = 100

with open(f"./Classification_Acc/OFedAvg_{data}_L{L}_p{prob}.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open(f"./Classification_Acc/OFedAvg_{data}_L{L}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

with open(f"./Classification_Acc/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob}.pkl","rb") as f:
    ofl_sel_mse3 = pickle.load(f)

with open(f"./Classification_Acc/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse4 = pickle.load(f)
    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
t3 = list(range(len(ofl_sel_mse3)))
t4 = list(range(len(ofl_sel_mse4)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
y3 = ofl_sel_mse3
y4 = ofl_sel_mse4
# plotting the points
plt.plot(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=1.0}$)')
plt.plot(t3, y3, 'red', label=r'OFedQIT ($\mathdefault{p=1.0}$), 95.1% reduce')
plt.plot(t2, y2, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)', linestyle='dashed')
plt.plot(t4, y4, 'red', label=r'OFedQIT ($\mathdefault{p=0.1}$), 95.1% reduce', linestyle='dashed')

plt.ylim([0.5, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('time index (t)')
# naming the y axis
plt.ylabel('Accuracy (t)')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig(f'./Figures/Classification_{data}_OFedQIT_p={prob}_b={b}_combinations_ver2.0.png', dpi=200, facecolor="white")
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

L = 1
L2 = 1

prob = 1.0
prob2 = 0.1
data = "Conductivity"
b = 1

with open(f"./Regression_mse/OFedAvg_{data}_L{L}_p{prob}.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

# with open(f"./Regression_mse/OFedAvg_{data}_L{L}_p{prob2}.pkl","rb") as f:
#     ofl_sel_mse2 = pickle.load(f)

# with open(f"./Regression_mse/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob}.pkl","rb") as f:
#     ofl_sel_mse3 = pickle.load(f)

with open(f"./Regression_mse/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse4 = pickle.load(f)
    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
t3 = list(range(len(ofl_sel_mse3)))
t4 = list(range(len(ofl_sel_mse4)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
y3 = ofl_sel_mse3
y4 = ofl_sel_mse4
# plotting the points
plt.plot(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=1.0}$)')
# plt.plot(t3, y3, 'red', label=r'OFedQIT ($\mathdefault{p=1.0}$), 96.8% reduce')
# plt.plot(t2, y2, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)', linestyle='dashed')
plt.plot(t4, y4, 'red', label=r'FedQOGD ($\mathdefault{p=0.1, s=1}$), 99.3% reduce')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('time index (t)')
# naming the y axis
plt.ylabel('MSE (t)')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig(f'./Figures/Regression_{data}_OFedQIT_p={prob}_b={b}_combinations_ver2.0.png', dpi=200, facecolor="white")
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

L = 1
L1 = 1
L2 = 1

prob = 1.0
prob2 = 0.1
data = "Occp_v3"
b = 100

with open(f"./Classification_Acc/OFedAvg_Occp_v2_L{L}_p{prob}.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

# with open(f"./Classification_Acc/OFedAvg_{data}_L{L}_p{prob2}.pkl","rb") as f:
#     ofl_sel_mse2 = pickle.load(f)

# with open(f"./Classification_Acc/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob}.pkl","rb") as f:
#     ofl_sel_mse3 = pickle.load(f)

with open(f"./Classification_Acc/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse4 = pickle.load(f)
    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
t3 = list(range(len(ofl_sel_mse3)))
t4 = list(range(len(ofl_sel_mse4)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
y3 = ofl_sel_mse3
y4 = ofl_sel_mse4
# plotting the points
plt.plot(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=1.0}$)')
# plt.plot(t3, y3, 'red', label=r'OFedQIT ($\mathdefault{p=1.0}$), 92.8% reduce')
# plt.plot(t2, y2, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)', linestyle='dashed')
plt.plot(t4, y4, 'red', label=r'FedQOGD ($\mathdefault{p=0.1, s=1}$), 98.5% reduce')

plt.ylim([0.5, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('time index (t)')
# naming the y axis
plt.ylabel('Accuracy (t)')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig(f'./Figures/Classification_{data}_OFedQIT_p={prob}_b={b}_combinations_ver2.0.png', dpi=200, facecolor="white")
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

L = 1
L1 = 1
L2 = 2

prob = 1.0
prob2 = 0.1
data = "MNIST"
b = 1000

with open(f"./Classification_Acc/OFedAvg_{data}_L{L}_p{prob}.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open(f"./Classification_Acc/OFedAvg_{data}_L{L}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

with open(f"./Classification_Acc/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob}.pkl","rb") as f:
    ofl_sel_mse3 = pickle.load(f)

with open(f"./Classification_Acc/OFedQIT_{data}_L{L2}_s1_b{b}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse4 = pickle.load(f)
    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
t3 = list(range(len(ofl_sel_mse3)))
t4 = list(range(len(ofl_sel_mse4)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
y3 = ofl_sel_mse3
y4 = ofl_sel_mse4
# plotting the points
# plt.plot(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=1.0}$)')
# plt.plot(t3, y3, 'red', label=r'OFedQIT ($\mathdefault{p=1.0}$), 95.4% reduce')
plt.plot(t2, y2, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)')
plt.plot(t4, y4, 'red', label=r'OFedQIT ($\mathdefault{p=0.1, s=1, L=2}$), 95.4% reduce')

plt.ylim([0.5, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('time index (t)')
# naming the y axis
plt.ylabel('Accuracy (t)')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig(f'./Figures/Classification_{data}_OFedQIT_p={prob}_b={b}_combinations_ver2.0.png', dpi=200, facecolor="white")
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

L = 1
L2 = 10

prob = 1.0
prob2 = 0.1
data = "Air"
b = 1

with open(f"./Regression_mse/OFedAvg_{data}_p{prob}.pkl","rb") as f:
    ofl_sel_mse = pickle.load(f)

with open(f"./Regression_mse/OFedAvg_{data}_p{prob2}.pkl","rb") as f:
    ofl_sel_mse2 = pickle.load(f)

with open(f"./Regression_mse/OFedQIT_{data}_L{L2}_s1_p{prob}.pkl","rb") as f:
    ofl_sel_mse3 = pickle.load(f)

with open(f"./Regression_mse/OFedQIT_{data}_L{L2}_s1_p{prob2}.pkl","rb") as f:
    ofl_sel_mse4 = pickle.load(f)
    
t1 = list(range(len(ofl_sel_mse)))
t2 = list(range(len(ofl_sel_mse2)))
t3 = list(range(len(ofl_sel_mse3)))
t4 = list(range(len(ofl_sel_mse4)))
y1 = ofl_sel_mse
y2 = ofl_sel_mse2
y3 = ofl_sel_mse3
y4 = ofl_sel_mse4
# plotting the points
# plt.plot(t1, y1, 'black', label=r'OFedAvg ($\mathdefault{p=1.0}$)')
# plt.plot(t3, y3, 'red', label=r'OFedQIT ($\mathdefault{p=1.0}$), 96.8% reduce')
plt.plot(t2, y2, 'black', label=r'OFedAvg ($\mathdefault{p=0.1}$)')
plt.plot(t4, y4, 'red', label=r'OFedQIT ($\mathdefault{p=0.1, s=1, L=10}$), 99.3% reduce')

plt.ylim([0, 1]) 
plt.legend(ncol = 1)

# naming the x axis
plt.xlabel('time index (t)')
# naming the y axis
plt.ylabel('MSE (t)')
plt.rcParams["font.family"] = "Times New Roman"
# giving a title to my graph
 
# function to show the plot
plt.grid()
plt.savefig(f'./Figures/Regression_{data}_OFedQIT_p={prob}_b={b}_combinations_ver2.0.png', dpi=200, facecolor="white")
plt.show()
